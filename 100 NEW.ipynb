# %%
import numpy as np
import pandas as pd

# %%
html = pd.DataFrame(np.random.randn(4, 4))

# %%
print(html.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.888548</td>
#       <td>2.355616</td>
#       <td>1.265535</td>
#       <td>0.536247</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.436245</td>
#       <td>0.572996</td>
#       <td>-0.276999</td>
#       <td>-0.104089</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.450676</td>
#       <td>1.611777</td>
#       <td>-2.442460</td>
#       <td>-2.904635</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.283388</td>
#       <td>0.161897</td>
#       <td>-1.106783</td>
#       <td>1.559651</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(html.to_html(columns=[0]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.888548</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.436245</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.450676</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.283388</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # DAY 28

# %%
with open ("C:\\Users\\D\\Documents\\DSN_GRID3_OYO_FRAMLANDS\\metadata.xml", "rt") as xmll:
    all = pd.read_xml(xmll.read(),elems_only=True)

# %%
all
# Out:
#                          CharacterString  LanguageCode  MD_CharacterSetCode  \
# 0   ab2986da-41ee-403c-8e9f-791b15da45d1           NaN                  NaN
# 1                                   None           NaN                  NaN
# 2                                   None           NaN                  NaN
# 3                                   None           NaN                  NaN
# 4                                   None           NaN                  NaN
# 5                                   None           NaN                  NaN
# 6                   ISO 19115:2003/19139           NaN                  NaN
# 7                                    1.0           NaN                  NaN
# 8                                   None           NaN                  NaN
# 9                                   None           NaN                  NaN
# 10                                  None           NaN                  NaN
# ...

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CharacterString        3 non-null      object
#  1   LanguageCode           0 non-null      float64
#  2   MD_CharacterSetCode    0 non-null      float64
#  3   CI_ResponsibleParty    0 non-null      float64
#  4   DateTime               1 non-null      object
#  5   MD_ReferenceSystem     0 non-null      float64
#  6   MD_DataIdentification  0 non-null      float64
#  7   MD_Distribution        0 non-null      float64
#  8   DQ_DataQuality         0 non-null      float64
# dtypes: float64(7), object(2)
# memory usage: 992.0+ bytes

# %%
m =["sunday","mike","suc","paul","sum"]
nm = [i for i in filter(lambda i:i.startswith("s"),m)]
print(nm)

# m = lambda y:y*2
# m(2)
# Out:
# ['sunday', 'suc', 'sum']

# %% [markdown]
# # read_xml() function can accept an XML string/file/URL and will parse nodes and attributes into a pandas DataFram

# %% [markdown]
# # DAY 29

# %%
xl = pd.DataFrame({"Name": ["PAUL", "OLA", "MIKE"],
                                "State": ["Lagos", "Oyo","Ekiti"],
                            "Capital": ["Ikeja", np.nan, "Ado-Ekiti"]})

# %%
print(xl.to_xml())
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <data>
#   <row>
#     <index>0</index>
#     <Name>PAUL</Name>
#     <State>Lagos</State>
#     <Capital>Ikeja</Capital>
#   </row>
#   <row>
#     <index>1</index>
#     <Name>OLA</Name>
#     <State>Oyo</State>
#     <Capital/>
#   </row>
#   <row>
#     <index>2</index>
#     <Name>MIKE</Name>
#     <State>Ekiti</State>
#     <Capital>Ado-Ekiti</Capital>
#   </row>
# </data>

# %%
print(xl.to_xml(root_name="geometry", row_name="objects"))
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <geometry>
#   <objects>
#     <index>0</index>
#     <Name>PAUL</Name>
#     <State>Lagos</State>
#     <Capital>Ikeja</Capital>
#   </objects>
#   <objects>
#     <index>1</index>
#     <Name>OLA</Name>
#     <State>Oyo</State>
#     <Capital/>
#   </objects>
#   <objects>
#     <index>2</index>
#     <Name>MIKE</Name>
#     <State>Ekiti</State>
#     <Capital>Ado-Ekiti</Capital>
#   </objects>
# </geometry>

# %%
pdm = xl.pivot_table(index='Name',
                                  columns='State',
                                  values=['Capital', 'State'],aggfunc='sum')

# %%
pdm
# Out:
#          Capital
# State      Ekiti  Lagos  Oyo
# Name
# MIKE   Ado-Ekiti    NaN  NaN
# OLA          NaN    NaN    0
# PAUL         NaN  Ikeja  NaN

# %%
DataFrame objects have an instance method to_xml which renders the contents of the DataFrame as an XML document

# %%
Working on how to render the contents of the DataFrame as an XML document with an instance method called to_xml in Data Frame objects

# %% [markdown]
# # DAY 31

# %%
import datetime
pivot_table = pd.DataFrame({ "first column": ["one", "one", "two", "three"] * 6, 
                                   "second column": ["A", "B", "C"] * 8, 
                                   "third column": ["foo", "foo", "foo", "bar", "bar", "bar"] * 4,
                                   "fourth column": np.random.randn(24), 
                                   "fifth column": np.random.randn(24), 
                            "sixth column": [datetime.datetime(2013, i, 1) for i in range(1, 13)] + [datetime.datetime(2013, i, 15)
                            for i in range(1, 13)],})

# %%
pivot_table
# Out:
#    first column second column third column  fourth column  fifth column  \
# 0           one             A          foo      -0.563871     -3.387574
# 1           one             B          foo       0.832055     -0.736010
# 2           two             C          foo       0.573033     -1.004485
# 3         three             A          bar       1.614231      1.096983
# 4           one             B          bar      -1.646182     -0.686796
# 5           one             C          bar       0.582294      1.055206
# 6           two             A          foo       0.788756      0.660935
# 7         three             B          foo      -1.661828     -1.885740
# 8           one             C          foo      -0.549538      0.847394
# 9           one             A          bar       0.510415      2.009458
# 10          two             B          bar       0.497855     -0.248175
# 11        three             C          bar       0.492917     -1.239892
# ...

# %%
pd.pivot_table(pivot_table , values="fourth column", index=["first column", "second column"], columns=["third column"])
# Out:
# third column                     bar       foo
# first column second column
# one          A             -0.947419 -0.404432
#              B             -0.847961  0.115344
#              C              0.806799 -1.271977
# three        A              0.372315       NaN
#              B                   NaN -0.358445
#              C              0.505101       NaN
# two          A                   NaN -0.417886
#              B             -0.259728       NaN
#              C                   NaN  0.496075

# %%
pd.pivot_table(pivot_table , values=["fourth column", "fifth column"], 
                  index=["second column"],
                  columns=["first column", "third column"],
                  aggfunc=np.sum)
# Out:
#               fifth column                                                   \
# first column           one               three                two
# third column           bar       foo       bar      foo       bar       foo
# second column
# A                 0.586330 -4.661413  1.161232      NaN       NaN  1.999851
# B                -1.076853 -0.549974       NaN -2.92253 -2.075021       NaN
# C                 1.118599  1.504443 -3.209585      NaN       NaN -0.843018
#
#               fourth column
# first column            one               three                 two
# third column            bar       foo       bar       foo       bar       foo
# second column
# A                 -1.894838 -0.808865  0.744630       NaN       NaN -0.835773
# B                 -1.695923  0.230689       NaN -0.716891 -0.519456       NaN
# C                  1.613598 -2.543953  1.010202       NaN       NaN  0.992150

# %% [markdown]
# # DAY 32

# %%
import matplotlib.pyplot as plt

# %%
ploting= pd.Series(np.random.randn(2000), index=pd.date_range("1/1/2000",periods=2000))
ploting= ploting.cumsum()
ploting.plot();

# %%
data = pd.DataFrame(np.random.randn(2000, 4), index=ts.index, columns=list("ABCD"))
data= data.cumsum()
plt.figure();
data.plot();

# %%
real = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()
real["A"] = pd.Series(list(range(len(real))))
real.plot(x="A", y="B");

# %% [markdown]
# # DAY 33

# %%
bar= pd.DataFrame(np.random.rand(10, 3), columns=["a", "b", "c"])
bar.plot.bar();

# %%
bar.plot.bar(stacked=True);

# %%
bar.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # DAY 34

# %%
plt.style.use('seaborn-whitegrid')
hdata = np.random.randn(1000)
plt.hist(hdata);

# %%
hiplt = pd.DataFrame({"a": np.random.randn(1000) + 1,
                    "b": np.random.randn(1000),
                    "c": np.random.randn(1000) - 1,},
                   columns=["a", "b", "c"],)
plt.figure();
hiplt.plot.hist(alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure();
hiplt.plot.hist(stacked=True, bins=20);

# %%
plt.figure();
hiplt["a"].plot.hist(orientation="horizontal", cumulative=True);

# %% [markdown]
# # DAY 35

# %%
mybox = pd.DataFrame(np.random.rand(10, 5), columns=["first", "second", "third", "fourth", "fifth"])
mybox.plot.box();

# %%
color = {"boxes": "DarkGreen","whiskers": "DarkOrange","medians": "DarkBlue","caps": "Gray",}
mybox.plot.box(color=color, sym="r+");

# %%
mybox.plot.box(vert=False, positions=[1, 4, 5, 6, 8]);

# %%
df = pd.DataFrame(np.random.rand(10, 5))
plt.figure();
bp = df.boxplot()

# %% [markdown]
# # DAY 36

# %%
dfig = pd.DataFrame(np.random.rand(12, 3), columns=["Col1", "Col2","Col3"])
dfig["X"] = pd.Series(["A", "A", "A",  "B", "B", "B","C","C","C"])
plt.figure();
bpig = dfig.boxplot(by="X")

# %%
dfig = pd.DataFrame(np.random.rand(10, 3), columns=["Col1", "Col2", "Col3"])
dfig["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])
dfig["Y"] = pd.Series(["A", "B", "A", "B", "A", "B", "A", "B", "A", "B"])
plt.figure();
bpig = dfig.boxplot(column=["Col1", "Col2"], by=["X", "Y"])

# %%
np.random.seed(1234)
df_box = pd.DataFrame(np.random.randn(50, 2))
df_box["g"] = np.random.choice(["A", "B"], size=50)
df_box.loc[df_box["g"] == "B", 1] += 3
bp = df_box.boxplot(by="g")

# %% [markdown]
# # DAY 37

# %%
areaplot= pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
areaplot.head()
# Out:
#           a         b         c         d
# 0  0.873276  0.351747  0.630133  0.357827
# 1  0.212820  0.223319  0.419564  0.072910
# 2  0.650839  0.755686  0.932101  0.376404
# 3  0.296927  0.371944  0.827699  0.901140
# 4  0.427304  0.002189  0.041965  0.141787

# %%
areaplot.plot.area();

# %%
areaplot.plot.area(stacked=False);

# %% [markdown]
# You can create area plots with Series.plot.area() and
# DataFrame.plot.area(). Area plots are stacked by default.
# Toproducestackedareaplot
# eachcolumnmustbeeitherallpositiveorallnegativevalues. When input data contains NaN, it will be automatically filled by 0. If you want to drop or
# fill by different values, use dataframe.dropna() or dataframe.fillna() beforecalling plot.

# %% [markdown]
# # DAY 38

# %%
dfsa = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])
dfsa["species"] = pd.Categorical(["setosa"] * 20 + ["versicolor"] * 20 + ["virginica"] * 10 ) 
dfsa.plot.scatter(x="a", y="b");

# %%
axdf = dfsa.plot.scatter(x="a", y="b", color="DarkBlue", label="Group 1")
dfsa.plot.scatter(x="c", y="d", color="DarkGreen", label="Group 2", ax=axdf);

# %%
dfsa.plot.scatter(x="a", y="b", c="species", cmap="viridis", s=50);

# %% [markdown]
# # DAY 39

# %%
piedf = pd.Series(3 * np.random.rand(4), index=["A", "B", "C", "D"], name="PAUL PIE PLOT")
piedf.plot.pie(figsize=(6, 6));

# %%
piedf.plot.pie(labels=["AA", "BB", "CC", "DD"],
                colors=["r", "g", "b", "c"],autopct="%.2f", fontsize=20, figsize=(6, 6),)
# Out:
# <AxesSubplot:ylabel='PAUL PIE PLOT'>

# %%
another = pd.Series([0.1] * 4, index=["a", "b", "c", "d"], name="OPAKUNBI PAUL")
another.plot.pie(figsize=(6, 6));
# Out:
# C:\Users\D\AppData\Roaming\Python\Python38\site-packages\pandas\plotting\_matplotlib\core.py:1666: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)

# %% [markdown]
# # DAY 41

# %%
databarh= pd.DataFrame({'name': ['paul', 'mike', 'ola','femi'], 'age': [15, 28, 10,18]})
mybarh= databarh.plot.barh(x='name', y='age')

# %%
mathematics = [59, 57, 60, 72, 70, 69, 88]
english = [83, 79, 70, 79, 57, 69, 86]
name = ['Paul', 'Olamide', 'John', 'Peter', 'Tife', 'Blessing', 'Mike']
com = pd.DataFrame({'Mathematics': mathematics,  'English': english}, index=name)
alplot = com.plot.barh()

# %%
alplot= com.plot.barh(stacked=True)

# %%
# m = 10

# %%
# m

# %%
alplot= com.plot.barh(stacked=True)

# %% [markdown]
# # DAY 42

# %%
kde = pd.Series([77,9,4.9,8.5,8,3,1,4,8,1])
all = kde.plot.kde()

# %%
data= pd.DataFrame({'male': [5, 1, 5.2, 3.6, 3.5, 4, 5],'female': [8, 5, 4.5, 5, 5.5, 9, 6],})
mydata = data.plot.kde()

# %%
okay = data.plot.kde(ind=[2,6.4,5.4,3,6,2,8,5,6,4])

# %%
kernel density estimation(KDE)
